# %% [markdown]
# <a href="https://colab.research.google.com/github/yanamalaanusha/anusha-icp1-spring-2021/blob/main/KDM_ICP8_(1)_(2)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textacy
import spacy
import textacy
# Out:
# ...
#      |████████████████████████████████| 184kB 5.7MB/s
# ...
#      |████████████████████████████████| 92kB 4.4MB/s
# ...
#      |████████████████████████████████| 1.9MB 7.1MB/s
# ...
#      |████████████████████████████████| 481kB 21.1MB/s
# ...
#   Created wheel for cytoolz: filename=cytoolz-0.11.0-cp37-cp37m-linux_x86_64.whl size=1223250 sha256=26dae580ae9579ac177f3466d20ba94bc1ed617714e3b344159fb9f908fc6a6f
#   Stored in directory: /root/.cache/pip/wheels/a1/32/3c/9c9926b510647cacdde744b2c7acdf1ccd5896fbb7f8d5df0c
# Successfully built cytoolz
# ...

# %%
# reading input files
f = open('file3.txt', 'r')
# loading en_core_web_sm model
nlp = spacy.load("en_core_web_sm")
doc = nlp(f.read())
f.close()

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Python PROPN nsubj
# is AUX ROOT
# an DET det
# interpreted VERB amod
# , PUNCT punct
# high ADJ amod
# - PUNCT punct
# level NOUN nmod
# and CCONJ cc
# general ADJ amod
# - PUNCT punct
# purpose NOUN conj
# programming NOUN compound
# language NOUN attr
# . PUNCT punct
# Python PROPN poss
# 's PART case
# design NOUN compound
# philosophy NOUN nsubj
# emphasizes VERB ROOT
# code NOUN compound
# readability NOUN dobj
# with ADP prep
# its DET poss
# notable ADJ amod
# use NOUN pobj
# of ADP prep
# significant ADJ amod
# indentation NOUN pobj
# . PUNCT punct
# Its DET poss
# language NOUN compound
# constructs NOUN nsubj
# and CCONJ cc
# object NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# approach NOUN conj
# aim VERB ROOT
# to PART aux
# help VERB xcomp
# programmers NOUN nsubj
# write VERB ccomp
# clear ADJ amod
# , PUNCT punct
# logical ADJ amod
# code NOUN dobj
# for ADP prep
# small ADJ amod
# and CCONJ cc
# large ADJ conj
# - PUNCT punct
# scale NOUN compound
# ...

# %%
tuples_list = []
#extracting triplet using textacy library
tuples = textacy.extract.subject_verb_object_triples(doc)
tuples_to_list = list(tuples)
if tuples_to_list != []:
    tuples_list.append(tuples_to_list)

# %%
print(tuples_list)
# Out:
# [[(design philosophy, emphasizes, code readability), (language constructs, aim, to help), (approach, aim, to help), (programmers, write, code), (It, supports, programming paradigms), (Guido van Rossum, began, working)]]
